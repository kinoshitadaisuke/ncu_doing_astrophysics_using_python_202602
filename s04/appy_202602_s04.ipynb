# %% [markdown]
# # Doing Astrophysics using Python
#
# - "Doing Astrophysics using Python"
#   - Instructor: Kinoshita Daisuke
#   - Classroom: S4-202
#   - Time: from 13:00 to 15:50 on Wednesday
#   - Semester: 2nd semester of academic year 2025
#     - from February 2026 to June 2026
#   - Course web page: https://s3b.astro.ncu.edu.tw/appy_202602/
#   - GitHub repository: https://github.com/kinoshitadaisuke/ncu_doing_astrophysics_using_python_202602

# %% [markdown]
# # Session 04: "Visualisation of data using Matplotlib"
#
# ## 18 March 2026
#
# ## Instructor: Kinoshita Daisuke

# %% [markdown]
# # 0. Installation of Python interpreter

# %%
# Run this cell to install Python 3.14

# !apt update
# !apt upgrade
# !apt install python3.14 python3.14-dev python3.14-full libpython3.14-dev
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.14 1
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.14 get-pip.py

# %%
# Run this cell to check the version of Python interpreter and pip command

# !python3.14 --version
# !pip --version

# %%
# Run this cell to install external Python modules necessary for this session.

# !pip install matplotlib astropy astroquery jplephem ipykernel importlib_metadata Pillow

# %% [markdown]
# # 1. Downloading a set of sample Python scripts for this course

# %%
# Run this cell to download a set of sample Python scripts for this course.

# !git clone https://github.com/kinoshitadaisuke/ncu_doing_astrophysics_using_python_202602.git

# %%
# Run this cell to move to the directory for this session.

# %cd ncu_doing_astrophysics_using_python_202602/s04

# %%
# Run this cell to show a list of files for this session.

# !ls -lF

# %% [markdown]
# # Matplotlib APIs

# %% [markdown]
# ## Making a plot using implicit pyplot interface

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_00_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_00_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_00_00.py -o appy_s04_00_00.png

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_00_00.png')

# %% [markdown]
# ## Making a plot using explicit Axes interface

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_00_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_00_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_00_01.py -o appy_s04_00_01.png

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_00_01.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_00_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_00_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_00_02.py -o appy_s04_00_02.png

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_00_02.png')

# %% [markdown]
# ## Making a plot using object-oriented interface

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_00_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_00_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_00_03.py -o appy_s04_00_03.png

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_00_03.png')

# %% [markdown]
# # Plotting lines and curves

# %% [markdown]
# ## Plotting a line

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_01_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_00.py -o appy_s04_01_00.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_01_00.png')

# %% [markdown]
# ## Plotting a curve

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_01_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_01.py -o appy_s04_01_01.png -r 200

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_01_01.png')

# %% [markdown]
# ## Plotting a sine curve

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_01_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_02.py -o appy_s04_01_02.png -r 300

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_01_02.png')

# %% [markdown]
# ## Plotting a circle

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_01_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_03.py -o appy_s04_01_03.png -r 250

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_01_03.png')

# %% [markdown]
# ## Plotting multiple lines/curves

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_01_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_04.py -o appy_s04_01_04.png -r 400

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_01_04.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_01_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_05.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_01_05.py -o appy_s04_01_05.png -r 450

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_01_05.png')

# %% [markdown]
# # Changing properties of lines/curves

# %% [markdown]
# ## Changing colours of lines/curves

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_02_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_02_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_02_00.py -o appy_s04_02_00.png -r 225

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_02_00.png')

# %% [markdown]
# ## Changing line styles

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_02_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_02_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_02_01.py -o appy_s04_02_01.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_02_01.png')

# %% [markdown]
# ## Changing line width

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_02_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_02_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_02_02.py -o appy_s04_02_02.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_02_02.png')

# %% [markdown]
# ## Specifying favourite colour, line style, and line width

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_02_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_02_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_02_03.py -o appy_s04_02_03.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_02_03.png')

# %% [markdown]
# # Plotting data points

# %% [markdown]
# ## Plotting a data point

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_03_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_00.py -o appy_s04_03_00.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_03_00.png')

# %% [markdown]
# ## Plotting multiple data points

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_03_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_01.py -o appy_s04_03_01.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_03_01.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_03_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_02.py -o appy_s04_03_02.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_03_02.png')

# %% [markdown]
# ## Plotting data points using specified marker types

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_03_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_03.py -o appy_s04_03_03.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_03_03.png')

# %% [markdown]
# ## Plotting data points of specified marker sizes

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_03_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_03_04.py -o appy_s04_03_04.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_03_04.png')

# %% [markdown]
# # Attaching error bars to data points

# %% [markdown]
# ## Attaching error bars along vertical axis

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_04_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_04_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_04_00.py -o appy_s04_04_00.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_04_00.png')

# %% [markdown]
# ## Attaching error bars along vertical axis and horizontal axis

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_04_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_04_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_04_01.py -o appy_s04_04_01.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_04_01.png')

# %% [markdown]
# # Using logarithmic scale for plots

# %% [markdown]
# ## Making a semi-log plot

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_05_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_05_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_05_00.py -o appy_s04_05_00.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_05_00.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_05_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_05_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_05_01.py -o appy_s04_05_01.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_05_01.png')

# %% [markdown]
# ## Making a log-log plot

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_05_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_05_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_05_02.py -o appy_s04_05_02.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_05_02.png')

# %% [markdown]
# # Dealing with date/time

# %% [markdown]
# ## Downloading data file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_06_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_06_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_06_00.py -o alf_ori.data https://s3b.astro.ncu.edu.tw/appy_202602/data/alf_ori.data

# %%
# Run this cell to find downloaded file.

# !ls -lF *.data

# %%
# Run this cell to show first 10 lines of the data file.

# !head -10 alf_ori.data

# %% [markdown]
# ## Reading a data file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_06_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_06_01.py

# %% [markdown]
# ## Making a lightcurve of Betelgeuse

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_06_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_06_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_06_02.py -o appy_s04_06_02.png alf_ori.data -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_06_02.png')

# %% [markdown]
# ## Changing ticks

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_06_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_06_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_06_03.py -o appy_s04_06_03.png alf_ori.data -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_06_03.png')

# %% [markdown]
# # Making histograms

# %% [markdown]
# ## Generating a set of random numbers

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_07_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_00.py -o appy_s04_07_00.data -m 100 -s 10 -n 1000

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show first 20 lines of data file.

# !head -20 appy_s04_07_00.data

# %% [markdown]
# ## Opening data file and reading data

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_07_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_01.py appy_s04_07_00.data

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_07_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_02.py appy_s04_07_00.data

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_07_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_03.py appy_s04_07_00.data

# %% [markdown]
# ## Making a histogram

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_07_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_04.py -a 50 -b 150 -w 5 appy_s04_07_00.data

# %% [markdown]
# ## Making a histogram using .bar () method

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_07_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_05.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_05.py -a 50 -b 150 -w 5 -o appy_s04_07_05.png -r 150 appy_s04_07_00.data

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_07_05.png')

# %% [markdown]
# ## Making a histogram using .hist () method

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_07_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_06.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_07_06.py -a 50 -b 150 -w 5 -o appy_s04_07_06.png -r 150 appy_s04_07_00.data

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_07_06.png')

# %% [markdown]
# # Making a scatter plot

# %% [markdown]
# ## Downloading Yale Bright Star Catalogue

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_08_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_00.py -b -v -o bsc5.gz https://cdsarc.cds.unistra.fr/ftp/V/50/catalog.gz

# %%
# Run this cell to find downloaded file.

# !ls -lF *.gz

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_00.py -o bsc5_readme.txt https://cdsarc.cds.unistra.fr/ftp/V/50/ReadMe

# %%
# Run this cell to find downloaded file.

# !ls -lF bsc5*

# %%
# Run this cell to read the README file.

# !cat bsc5_readme.txt

# %% [markdown]
# ## Reading information from the catalogue file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_08_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_01.py -m 1.5 bsc5.gz

# %% [markdown]
# ## Making HR diagram of the brightest stars

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_08_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_02.py -m 1.5 -o appy_s04_08_02.png -r 150 bsc5.gz

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_08_02.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_02.py -m 3.0 -o appy_s04_08_02b.png -r 150 bsc5.gz

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_08_02b.png')

# %% [markdown]
# ## Changing marker size

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_08_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_03.py -m 1.5 -o appy_s04_08_03.png -r 150 bsc5.gz

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_08_03.png')

# %% [markdown]
# ## Making a scatter plot

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_08_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_08_04.py -m 6.0 -o appy_s04_08_04.png -r 150 bsc5.gz

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_08_04.png')

# %% [markdown]
# # Making an animation

# %% [markdown]
# # A simple animation example

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_09_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_00.py -o appy_s04_09_00.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_09_00.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_09_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_01.py -a 7 -b 5 -o appy_s04_09_01.mp4 -r 150

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Run this cell to download file to your local computer.

# importing google.colab module
import google.colab

# downloading file
google.colab.files.download ('appy_s04_09_01.mp4')

# %% [markdown]
# ## Visualisation of orbital motion of planets

# %% [markdown]
# ### Downloading positions of planets

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_09_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_02.py -t 2026-04-01T12:00:00

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_09_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_03.py -t 2026-04-01T12:00:00

# %% [markdown]
# ### Plotting positions of planets

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_09_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_04.py -t 2026-04-01T12:00:00 -o appy_s04_09_04.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_09_04.png')

# %% [markdown]
# ### Making an animation

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_09_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_09_05.py -h

# %%
# Run this cell to execute the script.

#
# It takes a few minutes to execute this cell.
#

# !python3.14 appy_s04_09_05.py -t 2026-04-01T12:00:00 -s 8.0 -n 900 -o appy_s04_09_05.mp4

# %%
# Run this cell to download file to your local computer.

# importing google.colab module
import google.colab

# downloading file
google.colab.files.download ('appy_s04_09_05.mp4')

# %% [markdown]
# # Making 3-dimensional plots

# %% [markdown]
# ## Making 3D scatter plot

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_10_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_10_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_10_00.py -o appy_s04_10_00.png -r 150 -m 1000 -s 300 -n 10000

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_10_00.png')

# %% [markdown]
# ## Making 3D line plot

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_10_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_10_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_10_01.py -o appy_s04_10_01.png -r 150

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_10_01.png')

# %% [markdown]
# # 3D structure of inner solar system

# %% [markdown]
# ## Making a movie of orbital motion of planets and 50 asteroids

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_11_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_11_00.py -h

# %%
# Run this cell to execute the script.

#
# IMPORTANT: Execution of this cell may take 1-2 hours.
#

# !python3.14 appy_s04_11_00.py -t 2026-04-01T12:00:00 -a 50 -n 600 -s 12

# %%
# Run this cell to find newly created files.

# !ls -lF solsys_3d1

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('solsys_3d1/000000.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_11_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_11_01.py

# %%
# Run this cell to download file to your local computer.

# importing google.colab module
import google.colab

# downloading file
google.colab.files.download ('solsys_3d1.mp4')

# %% [markdown]
# ## Changing camera viewing angle

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_11_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_11_02.py -h

# %%
# Run this cell to execute the script.

#
# IMPORTANT: Execution of this cell may take 1-2 hours.
#

# !python3.14 appy_s04_11_02.py -t 2026-04-01T12:00:00 -a 50 -n 600 -s 12

# %%
# Run this cell to find newly created files.

# !ls -lF solsys_3d2

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('solsys_3d2/000000.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_11_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_11_03.py

# %%
# Run this cell to download file to your local computer.

# importing google.colab module
import google.colab

# downloading file
google.colab.files.download ('solsys_3d2.mp4')

# %% [markdown]
# ## Making a movie of orbital motion of planets and 3000 asteroids

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_11_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_11_04.py -h

# %%
# Run this cell to execute the script.

#
# IMPORTANT: Execution of this cell may take about one day or even more.
#

# !python3.14 appy_s04_11_04.py -t 2026-04-01T12:00:00 -a 3000 -n 3000 -s 12

# %%
# Run this cell to find newly created files.

# !ls -lF solsys_3d3

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('solsys_3d3/000000.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_11_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_11_05.py

# %%
# Run this cell to download file to your local computer.

# importing google.colab module
import google.colab

# downloading file
google.colab.files.download ('solsys_3d3.mp4')

# %% [markdown]
# # Making polar plots

# %% [markdown]
# ## Simple polar plot

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_12_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_12_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_12_00.py -o appy_s04_12_00.png 1 2 3

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_12_00.png')

# %% [markdown]
# ## Plotting the position of the Moon

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_12_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_12_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_12_01.py -o appy_s04_12_01.png -t 2026-04-01T12:00:00

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_12_01.png')

# %% [markdown]
# ## Plotting the position of the Sun, the Moon, and planets

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_12_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_12_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_12_02.py -o appy_s04_12_02.png -t 2026-04-01T12:00:00

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_12_02.png')

# %% [markdown]
# ## Plotting the position of the Sun, the Moon, planets, and stars

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_12_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_12_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_12_03.py -o appy_s04_12_03.png -t 2026-04-01T12:00:00

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_12_03.png')

# %% [markdown]
# # Filling an area

# %% [markdown]
# ## Downloading data

# %%
# Run this cell to download data file.

# !python3.14 appy_s04_08_00.py -v -o tokyo_temp.data https://s3b.astro.ncu.edu.tw/appy_202602/data/tokyo_temp.data

# %%
# Run this cell to find downloaded file.

# !ls -lF *.data

# %%
# Run this cell to show the content of the data file.

# !head -20 tokyo_temp.data

# %% [markdown]
# ## Visualising temperature data

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_13_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_13_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_13_00.py -o appy_s04_13_00.png -r 150 -i tokyo_temp.data

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_13_00.png')

# %% [markdown]
# # Making a pie chart

# %% [markdown]
# ## Making a simple pie chart

# %%
# Run this cell to download data file.

# !python3.14 appy_s04_08_00.py -v -o elements.data https://s3b.astro.ncu.edu.tw/appy_202602/data/elements.data

# %%
# Run this cell to find downloaded file.

# !ls -lF *.data

# %%
# Run this cell to show the content of the data file.

# !cat elements.data

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_14_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_14_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_14_00.py -o appy_s04_14_00.png -r 150 -i elements.data

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_14_00.png')

# %% [markdown]
# ## Making one more pie chart

# %%
# Run this cell to download data file.

# !python3.14 appy_s04_08_00.py -o energydensity.data https://s3b.astro.ncu.edu.tw/appy_202602/data/energydensity.data

# %%
# Run this cell to find downloaded file.

# !ls -lF *.data

# %%
# Run this cell to show the content of the data file.

# !cat energydensity.data

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_14_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_14_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_14_01.py -o appy_s04_14_01.png -r 150 -i energydensity.data

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_14_01.png')

# %% [markdown]
# # Making a contour map

# %% [markdown]
# ## Downloading a FITS image

# %%
# Run this cell to download data file.

# !python3.14 appy_s04_08_00.py -b -o hltau_alma.fits http://jvo.nao.ac.jp/skynode/do/download/alma/public/cube_primary/ALMA01424653_00_00_00

# %%
# Run this cell to find downloaded file.

# !ls -lF *.fits

# %%
# Run this cell to check file type of downloaded file.

# !file hltau_alma.fits

# %% [markdown]
# ## Reading a FITS file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_15_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_15_00.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_15_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_15_01.py

# %% [markdown]
# ## Making a contour map

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_15_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_15_02.py

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_15_02.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_15_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_15_03.py

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_15_03.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_15_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_15_04.py

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_15_04.png')

# %% [markdown]
# ## Making a filled contour map

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_15_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_15_05.py

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_15_05.png')

# %% [markdown]
# # Plotting images

# %% [markdown]
# ## Plotting a JPEG image

# %%
# Run this cell to download a JPEG image.

# !python3 appy_s04_08_00.py -v -b -o campus_map.jpg https://www.ncu.edu.tw/var/file/0/1000/img/3/425004547.jpg

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.jpg

# %%
# Run this cell to check the format of downloaded file.

# !file campus_map.jpg

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_16_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_16_00.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_16_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_16_01.py

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_16_01.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_16_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_16_02.py

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_16_02.png')

# %% [markdown]
# # Drawing vectors

# %%
# Run this cell to show the source code of the script.

# !cat appy_s04_17_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s04_17_00.py

# %%
# Run this cell to display a PNG image.

# importing IPython module
import IPython.display

# displaying image
IPython.display.Image ('appy_s04_17_00.png')

# %% [markdown]
# # End of this notebook
