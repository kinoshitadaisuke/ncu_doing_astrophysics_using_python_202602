# %% [markdown]
# # Doing Astrophysics using Python
#
# - "Doing Astrophysics using Python"
#   - Instructor: Kinoshita Daisuke
#   - Classroom: S4-202
#   - Time: from 13:00 to 15:50 on Wednesday
#   - Semester: 2nd semester of academic year 2025
#     - from February 2026 to June 2026
#   - Course web page: https://s3b.astro.ncu.edu.tw/appy_202602/
#   - GitHub repository: https://github.com/kinoshitadaisuke/ncu_doing_astrophysics_using_python_202602

# %% [markdown]
# # Session 11: "Estimating ages of star clusters"
#
# ## 06 May 2026
#
# ## Instructor: Kinoshita Daisuke

# %% [markdown]
# # 0. Installation of Python interpreter

# %%
# Run this cell to install Python 3.14

# !apt update
# !apt upgrade
# !apt install python3.14 python3.14-dev python3.14-full libpython3.14-dev
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.14 1
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.14 get-pip.py

# %%
# Run this cell to check the version of Python interpreter and pip command

# !python3.14 --version
# !pip --version

# %%
# Run this cell to install external Python packages.

# !pip install matplotlib matplotlib-inline numpy scipy astropy astroquery importlib_metadata

# %% [markdown]
# # 1. Downloading a set of sample Python scripts for this course

# %%
# Run this cell to download a set of sample Python scripts for this course.

# !git clone https://github.com/kinoshitadaisuke/ncu_doing_astrophysics_using_python_202602.git

# %%
# Run this cell to move to the directory for this session.

# %cd ncu_doing_astrophysics_using_python_202602/s11

# %%
# Run this cell to show a list of files for this session.

# !ls -lF

# %% [markdown]
# # 2. Check of availability of required Python packages

# %% [markdown]
# ## 2.1 Availability check of astroquery package

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_00_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_00_00.py

# %% [markdown]
# ## 2.2 More flexible Python script for availability check of packages

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_00_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_00_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_00_01.py astropy

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_00_01.py numpy scipy matplotlib

# %% [markdown]
# # 3. Using a name resolver

# %% [markdown]
# ## 3.1 Using Astroquery to get the coordinate

# %% [markdown]
# ### --- IMPORTANT NOTE ---
#
# To execute the script "appy_s11_01_00.py", make sure to install the latest version of Astroquery.
#
# https://pypi.org/project/astroquery/

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_01_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_00.py

# %% [markdown]
# ## 3.2 Making a flexible script for name resolving

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_01_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py Betelgeuse

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py "Crab Nebula"

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py M1

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py "Sgr A*"

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py "SN 1987A"

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py "3C 273"

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py Vega Altair

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_01_01.py "Andromeda Galaxy" Praesepe Pleiades

# %% [markdown]
# # 4. Downloading DSS images

# %% [markdown]
# ## 4.1 Downloading DSS images using Astroquery

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_02_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.fits

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_02_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_01.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m1.png')

# %% [markdown]
# ## 4.2 Downloading DSS image of a given celestial object

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_02_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_02.py -s "DSS2 Red" -t M2 -f 30 -o m2.fits

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.fits

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_02_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_03.py -i m2.fits -o m2.png -c cool -n "Globular Cluster M2"

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m2.png')

# %% [markdown]
# ## 4.3 Making a PNG file without saving a FITS file

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_02_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -t M81 -o m81.png -s SDSSg -f 40 -c inferno -n "Spiral Galaxy M81"

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m81.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -t "Stephan's Quintet" -o quintet.png -s SDSSr -c ocean -f 30 -n "Stephan's Quintet"

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('quintet.png')

# %% [markdown]
# # 5. Downloading Gaia DR3 Catalogue

# %% [markdown]
# ## 5.1 Retrieving Gaia Catalogue

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_03_00.py

# %%
# Run this cell to execute the script.

#
# It takes about 10 min to execute this cell.
# If you are in the classroom, run the next cell instead of this cell.
#

# !python3.14 appy_s11_03_00.py

# %%
# Run this cell to download Gaia DR3 data.

# !sh appy_s11_fetch_m3.sh

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.vot.gz

# %%
# Run this cell to find file type of newly downloaded file.

# !file m3.vot.gz

# %% [markdown]
# ## 5.2 Making a flexible script to download Gaia DR3 data

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_03_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_03_01.py -h

# %%
# Run this cell to execute the script.

#
# It takes about 10 min to execute this cell.
# If you are in the classroom, run the next cell instead of this cell.
#

# !python3.14 appy_s11_03_01.py -t M4 -o m4.vot.gz -r 30

# %%
# Run this cell to download Gaia DR3 data.

# !sh appy_s11_fetch_m4.sh

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.vot.gz

# %%
# Run this cell to find newly downloaded file.

# !file m4.vot.gz

# %% [markdown]
# # 6. Reading VOTable files

# %% [markdown]
# ## 6.1 Reading a VOTable file

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_04_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_04_00.py

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_04_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_04_01.py

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_04_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_04_02.py

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_04_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_04_03.py

# %%
# Run this cell to find newly created file.

# !ls -lF m3.*

# %%
# Run this cell to show the file "m3.list".

# !head -20 m3.list

# %% [markdown]
# ## 6.2 Reading a VOTable file specified by a command-line argument

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_04_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_04_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_04_04.py -v -i m4.vot.gz -o m4.list

# %%
# Run this cell to find newly created file.

# !ls -lF *.list

# %%
# Run this cell to show the file "m3.list".

# !head -20 m4.list

# %% [markdown]
# # 7. Colour-magnitude diagram of open cluster NGC 2547

# %% [markdown]
# ## 7.1 Downloading DSS image of NGC 2547

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -t "NGC 2547" -f 60 -o ngc2547.png -n "NGC 2547" -s "DSS2 Red" -c inferno

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547.png')

# %% [markdown]
# ## 7.2 Downloading Gaia DR3 catalogue

# %%
# Run this cell to execute the script.

#
# It takes about 10 min to execute this cell.
# If you are in the classroom, run the next cell instead of this cell.
#

# !python3.14 appy_s11_03_01.py -t "NGC 2547" -o ngc2547.vot.gz -r 45

# %%
# Run this cell to download Gaia DR3 data.

# !sh appy_s11_fetch_ngc2547.sh

# %% [markdown]
# ## 7.3 Visualising positions of stars

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_00.py -i ngc2547.vot.gz -o ngc2547_stars.png -t "NGC 2547"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_stars.png')

# %% [markdown]
# ## 7.4 Errors of Gaia measurements

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_01.py -i ngc2547.vot.gz -o ngc2547_err_ra.png -t "Errors of RA measurements"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_err_ra.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_02.py -i ngc2547.vot.gz -o ngc2547_err_dec.png -t "Errors of Dec measurements"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_err_dec.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_03.py -i ngc2547.vot.gz -o ngc2547_err_pm_ra.png -t "Proper motion relative error in RA"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_err_pm_ra.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_04.py -i ngc2547.vot.gz -o ngc2547_err_pm_dec.png -t "Proper motion relative error in Dec"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_err_pm_dec.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_05.py -i ngc2547.vot.gz -o ngc2547_err_parallax.png -t "SNR of parallax measurements"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_err_parallax.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_06.py -i ngc2547.vot.gz -o ngc2547_err_g.png -t "SNR of g-band measurements"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_err_g.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_07.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_07.py -i ngc2547.vot.gz -o ngc2547_err_b.png -t "SNR of b-band measurements"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_err_b.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_08.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_08.py -i ngc2547.vot.gz -o ngc2547_err_r.png -t "SNR of r-band measurements"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_err_r.png')

# %% [markdown]
# ## 7.5 Distribution of distances of stars

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_09.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_09.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_09.py -i ngc2547.vot.gz -o ngc2547_dist.png -a 0 -b 1000 -n 100

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_dist.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_09.py -i ngc2547.vot.gz -o ngc2547_dist2.png -a 300 -b 500 -n 40

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_dist2.png')

# %% [markdown]
# ## 7.6 Selecting stars by distance

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_10.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_10.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_10.py -i ngc2547.vot.gz -o ngc2547_candidates.list -a 365 -b 415

# %%
# Find newly created file.

# !ls -lF *.list

# %% [markdown]
# ## 7.7 Proper motion of selected stars

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_11.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_11.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_11.py -i ngc2547_candidates.list -o ngc2547_pm1.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_pm1.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_12.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i ngc2547_candidates.list -o ngc2547_pm2.png -a1 -12 -a2 -3 -d1 2 -d2 11

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_pm2.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i ngc2547_candidates.list -o ngc2547_pm3.png -a1 -10 -a2 -7 -d1 3 -d2 6

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_pm3.png')

# %% [markdown]
# ## 7.8 Further selection of stars by proper motion

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_13.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_13.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_13.py -i ngc2547_candidates.list -a1 -9.5 -a2 -8.0 -d1 3.5 -d2 5.0

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_14.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_14.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_14.py -i ngc2547_candidates.list -o ngc2547_pm4.png -a1 -10 -a2 -7 -d1 3 -d2 6 0.50 0.75 1.00 1.25 1.50

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_pm4.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_15.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_15.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_15.py -i ngc2547_candidates.list -o ngc2547_candidates2.list -a1 -10 -a2 -7 -d1 3 -d2 6 -r 0.75

# %%
# Run this cell to find newly created file.

# !ls -lF ngc2547*.list

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_16.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_16.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_16.py -i ngc2547_candidates2.list -o ngc2547_pm5.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_pm5.png')

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_05_17.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_17.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_17.py -i ngc2547_candidates2.list -o ngc2547_hr.png -t "Open cluster NGC 2547"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_hr.png')

# %% [markdown]
# # 8. Constraining the age of NGC 2547

# %% [markdown]
# ## 8.1 Downloading data

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_06_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_00.py

# %% [markdown]
# ## 8.2 Reading data file

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_06_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_01.py

# %% [markdown]
# ## 8.3 Visualising location of the main-sequence

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_06_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_02.py -i ngc2547_candidates2.list -m ms.data -o ngc2547_hr2.png -t "Open cluster NGC 2547"

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc2547_hr2.png')

# %% [markdown]
# # 9. Colour-magnitude diagram of open cluster M39

# %% [markdown]
# ## 9.1. Downloading DSS image of M39

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -t M39 -f 90 -o m39.png -n M39 -s "DSS2 Red" -c bone

# %%
# Run this cell to find downloaded file.

# !ls -lF m39.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39.png')

# %% [markdown]
# ## 9.2. Downloading Gaia DR3 data

# %%
# Run this cell to execute the script.

#
# It takes about 10 min to execute this cell.
# If you are in the classroom, run the next cell instead of this cell.
#

# !python3.14 appy_s11_03_01.py -t M39 -o m39.vot.gz -r 45

# %%
# Run this cell to download Gaia DR3 data.

# !sh appy_s11_fetch_m39.sh

# %%
# Run this cell to find downloaded file.

# !ls -lF *.vot.gz

# %% [markdown]
# ## 9.3 Converting VOTable file into text file

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_07_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_00.py -i m39.vot.gz -o m39.list

# %% [markdown]
# ## 9.4. Visualising distance distribution of stars

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_07_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i m39.list -o m39_dist.png -a 0 -b 1000 -n 200

# %%
# Run this cell to find downloaded file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_dist.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i m39.list -o m39_dist2.png -a 250 -b 350 -n 50

# %%
# Run this cell to find downloaded file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_dist2.png')

# %% [markdown]
# ## 9.5. Selecting stars by distance

# %%
# Run this cell to show the source code of this script.

# !cat appy_s11_07_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_02.py -i m39.list -o m39_candidates.list -a 280 -b 310

# %%
# Run this cell to find newly created file.

# !ls -lF *.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 m39_candidates.list | cut -b -80

# %%
# Run this cell to count number of selected stars.

# !grep -v '#' m39_candidates.list | wc

# %% [markdown]
# ## 9.6. Proper motion of star cluster member candidates

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_11.py -i m39_candidates.list -o m39_pm1.png

# %%
# Run this cell to find newly created file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_pm1.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i m39_candidates.list -o m39_pm2.png -a1 -12 -a2 -2 -d1 -25 -d2 -15

# %%
# Run this cell to find newly created file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_pm2.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i m39_candidates.list -o m39_pm3.png -a1 -10 -a2 -5 -d1 -22 -d2 -17

# %%
# Run this cell to find newly created file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_pm3.png')

# %% [markdown]
# ## 9.7. Further selection of stars by proper motion

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_13.py -i m39_candidates.list -a1 -8.5 -a2 -6.5 -d1 -21 -d2 -19

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_14.py -i m39_candidates.list -o m39_pm4.png -a1 -8.5 -a2 -6.5 -d1 -20.75 -d2 -18.75 0.50 0.75 1.00 1.25 1.50

# %%
# Run this cell to find newly created file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_pm4.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_15.py -i m39_candidates.list -o m39_candidates2.list -a1 -8.5 -a2 -6.5 -d1 -20.75 -d2 -18.75 -r 0.75

# %%
# Run this cell to find newly created file.

# !ls -lF m39*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 m39_candidates2.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' m39_candidates2.list | wc

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_16.py -i m39_candidates2.list -o m39_pm5.png

# %%
# Run this cell to find newly created file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_pm5.png')

# %% [markdown]
# ## 9.8. Constructing colour-magnitude diagram of M39

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_17.py -i m39_candidates2.list -o m39_hr.png -t "Open cluster M39"

# %%
# Run this cell to find newly created file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_hr.png')

# %% [markdown]
# ## 9.9. Superimposing synthetic main-sequence

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_02.py -i m39_candidates2.list -o m39_hr2.png -t "Open cluster M39"

# %%
# Run this cell to find newly created file.

# !ls -lF m39*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m39_hr2.png')

# %% [markdown]
# # 10. Colour-magnitude diagram of open cluster IC 4756

# %% [markdown]
# ## 10.1. Downloading DSS image of IC 4756

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -t "IC 4756" -f 90 -o ic4756.png -n "IC 4756" -s "DSS2 Red" -c inferno

# %%
# Run this cell to find downloaded file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756.png')

# %% [markdown]
# ## 10.2. Downloading Gaia DR3 data

# %%
# Run this cell to execute the script.

#
# It takes about 10 min to execute this cell.
# If you are in the classroom, run the next cell instead of this cell.
#

# !python3.14 appy_s11_03_01.py -t "IC 4756" -o ic4756.vot.gz -r 30

# %%
# Run this cell to download Gaia DR3 data.

# !sh appy_s11_fetch_ic4756.sh

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.vot.gz

# %% [markdown]
# ## 10.3. Visualising distance distribution of stars

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_00.py -i ic4756.vot.gz -o ic4756.list

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i ic4756.list -o ic4756_dist.png -a 0 -b 1000 -n 200

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_dist.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i ic4756.list -o ic4756_dist2.png -a 400 -b 560 -n 80

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_dist2.png')

# %% [markdown]
# ## 10.4. Selecting stars by distance

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_02.py -i ic4756.list -o ic4756_candidates.list -a 430 -b 510

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 ic4756_candidates.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' ic4756_candidates.list | wc

# %% [markdown]
# ## 10.5. Proper motion of star cluster member candidates

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_11.py -i ic4756_candidates.list -o ic4756_pm1.png

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_pm1.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i ic4756_candidates.list -o ic4756_pm2.png -a1 -15 -a2 15 -d1 -20 -d2 10

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_pm2.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i ic4756_candidates.list -o ic4756_pm3.png -a1 -1 -a2 4 -d1 -7.5 -d2 -2.5

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_pm3.png')

# %% [markdown]
# ## 10.6. Further selection of stars by proper motion

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_13.py -i ic4756_candidates.list -a1 0 -a2 3 -d1 -6.5 -d2 -3.5

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_14.py -i ic4756_candidates.list -o ic4756_pm4.png -a1 0 -a2 3 -d1 -6.5 -d2 -3.5 0.50 0.75 1.00 1.25 1.50

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_pm4.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_15.py -i ic4756_candidates.list -o ic4756_candidates2.list -a1 0 -a2 3 -d1 -6.5 -d2 -3.5 -r 0.75

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 ic4756_candidates2.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' ic4756_candidates2.list | wc

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_16.py -i ic4756_candidates2.list -o ic4756_pm5.png

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_pm5.png')

# %% [markdown]
# ## 10.7. Constructing colour-magnitude diagram of IC 4756

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_17.py -i ic4756_candidates2.list -o ic4756_hr.png -t "Open Cluster IC 4756"

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_hr.png')

# %% [markdown]
# ## 10.8. Superimposing synthetic main-sequence

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_02.py -i ic4756_candidates2.list -m ms.data -o ic4756_hr2.png -t "Open Cluster IC 4756"

# %%
# Run this cell to find newly created file.

# !ls -lF ic4756*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ic4756_hr2.png')

# %% [markdown]
# # 11. Colour-magnitude diagram of open cluster M67

# %% [markdown]
# ## 11.1. Downloading SDSS image of M67

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -t M67 -f 90 -o m67.png -n M67 -s SDSSr -c magma

# %%
# Run this cell to find downloaded file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67.png')

# %% [markdown]
# ## 11.2. Downloading Gaia DR3 data

# %%
# Run this cell to execute the script.

#
# It takes about 10 min to execute this cell.
# If you are in the classroom, run the next cell instead of this cell.
#

# !python3.14 appy_s11_03_01.py -t M67 -o m67.vot.gz -r 45

# %%
# Run this cell to download Gaia DR3 data.

# !sh appy_s11_fetch_m67.sh

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.vot.gz

# %% [markdown]
# ## 11.3. Visualising distance distribution of stars

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_00.py -i m67.vot.gz -o m67.list

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i m67.list -o m67_dist.png -a 0 -b 1500 -n 150

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_dist.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i m67.list -o m67_dist2.png -a 700 -b 1050 -n 70

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_dist2.png')

# %% [markdown]
# ## 11.4. Selecting stars by distance

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_02.py -i m67.list -o m67_candidates.list -a 750 -b 1000

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 m67_candidates.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' m67_candidates.list | wc

# %% [markdown]
# ## 11.5. Proper motion of star cluster member candidates

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_11.py -i m67_candidates.list -o m67_pm1.png

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_pm1.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i m67_candidates.list -o m67_pm2.png -a1 -16 -a2 -6 -d1 -8 -d2 2

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_pm2.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i m67_candidates.list -o m67_pm3.png -a1 -13.5 -a2 -8.5 -d1 -5.5 -d2 -0.5

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_pm3.png')

# %% [markdown]
# ## 11.6. Further selection of stars by proper motion

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_13.py -i m67_candidates.list -a1 -13.5 -a2 -8.5 -d1 -5.5 -d2 -0.5

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_14.py -i m67_candidates.list -o m67_pm4.png -a1 -13.5 -a2 -8.5 -d1 -5.5 -d2 -0.5 0.50 0.75 1.00 1.25 1.50

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_pm4.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_15.py -i m67_candidates.list -o m67_candidates2.list -a1 -13.5 -a2 -8.5 -d1 -5.5 -d2 -0.5 -r 0.75

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 m67_candidates2.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' m67_candidates2.list | wc

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_16.py -i m67_candidates2.list -o m67_pm5.png

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_pm5.png')

# %% [markdown]
# ## 11.7. Constructing colour-magnitude diagram of M67

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_17.py -i m67_candidates2.list -o m67_hr.png -t "Open Cluster M67"

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_hr.png')

# %% [markdown]
# ## 11.8. Superimposing synthetic main-sequence

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_02.py -i m67_candidates2.list -o m67_hr2.png -t "Open Cluster M67"

# %%
# Run this cell to find newly created file.

# !ls -lF m67*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m67_hr2.png')

# %% [markdown]
# # 12. Colour-magnitude diagram of globular cluster M4

# %% [markdown]
# ## 12.1. Downloading DSS image of M4

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -t M4 -f 90 -o m4.png -n M4 -s "DSS2 Red" -c copper

# %%
# Run this cell to find downloaded file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4.png')

# %% [markdown]
# ## 12.2. Downloading Gaia DR3 data

# %%
# Run this cell to execute the script.

#
# It takes about 10 min to execute this cell.
# If you are in the classroom, run the next cell instead of this cell.
#

# !python3.14 appy_s11_03_01.py -t M4 -o m4.vot.gz -r 45

# %%
# Run this cell to download Gaia DR3 data.

# !sh appy_s11_fetch_m4.sh

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.vot.gz

# %% [markdown]
# ## 12.3. Visualising distance distribution of stars

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_00.py -i m4.vot.gz -o m4.list

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i m4.list -o m4_dist.png -a 0 -b 5000 -n 250

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_dist.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i m4.list -o m4_dist2.png -a 1200 -b 2400 -n 120

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_dist2.png')

# %% [markdown]
# ## 12.4. Selecting stars by distance

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_02.py -i m4.list -o m4_candidates.list -a 1400 -b 2200

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 m4_candidates.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' m4_candidates.list | wc

# %% [markdown]
# ## 12.5. Proper motion of star cluster member candidates

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_11.py -i m4_candidates.list -o m4_pm1.png

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_pm1.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i m4_candidates.list -o m4_pm2.png -a1 -22 -a2 -2 -d1 -29 -d2 -9

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_pm2.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i m4_candidates.list -o m4_pm3.png -a1 -15 -a2 -10 -d1 -21.5 -d2 -16.5

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_pm3.png')

# %% [markdown]
# ## 12.6. Further selection of stars by proper motion

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_13.py -i m4_candidates.list -a1 -15 -a2 -10 -d1 -21.5 -d2 -16.5

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_14.py -i m4_candidates.list -o m4_pm4.png -a1 -15 -a2 -10 -d1 -21.5 -d2 -16.5 0.50 0.75 1.00 1.25 1.50

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_pm4.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_15.py -i m4_candidates.list -o m4_candidates2.list -a1 -15 -a2 -10 -d1 -21.5 -d2 -16.5 -r 1.50

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 m4_candidates2.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' m4_candidates2.list | wc

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_16.py -i m4_candidates2.list -o m4_pm5.png

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_pm5.png')

# %% [markdown]
# ## 12.7. Constructing colour-magnitude diagram of M4

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_17.py -i m4_candidates2.list -o m4_hr.png -t "Globular Cluster M4"

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_hr.png')

# %% [markdown]
# ## 12.8. Superimposing synthetic main-sequence

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_02.py -i m4_candidates2.list -o m4_hr2.png -t "Globular Cluster M4"

# %%
# Run this cell to find newly created file.

# !ls -lF m4*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('m4_hr2.png')

# %% [markdown]
# # 13. Colour-magnitude diagram of globular cluster NGC 6397

# %% [markdown]
# ## 13.1. Downloading DSS image of NGC 6397

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_02_04.py -t "NGC 6397" -f 90 -o ngc6397.png -n "NGC 6397" -s "DSS2 Red" -c viridis

# %%
# Run this cell to find downloaded file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397.png')

# %% [markdown]
# ## 13.2. Downloading Gaia DR3 data

# %%
# Run this cell to execute the script.

#
# It takes about 10 min to execute this cell.
# If you are in the classroom, run the next cell instead of this cell.
#

# !python3.14 appy_s11_03_01.py -t "NGC 6397" -o ngc6397.vot.gz -r 30

# %%
# Run this cell to download Gaia DR3 data.

# !sh appy_s11_fetch_ngc6397.sh

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.vot.gz

# %% [markdown]
# ## 13.3. Visualising distance distribution of stars

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_00.py -i ngc6397.vot.gz -o ngc6397.list

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i ngc6397.list -o ngc6397_dist.png -a 0 -b 5000 -n 250

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_dist.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_01.py -i ngc6397.list -o ngc6397_dist2.png -a 1800 -b 3200 -n 70

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_dist2.png')

# %% [markdown]
# ## 13.4. Selecting stars by distance

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_07_02.py -i ngc6397.list -o ngc6397_candidates.list -a 2000 -b 3000

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 ngc6397_candidates.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' ngc6397_candidates.list | wc

# %% [markdown]
# ## 13.5. Proper motion of star cluster member candidates

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_11.py -i ngc6397_candidates.list -o ngc6397_pm1.png

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_pm1.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i ngc6397_candidates.list -o ngc6397_pm2.png -a1 -2 -a2 8 -d1 -23 -d2 -13

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_pm2.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_12.py -i ngc6397_candidates.list -o ngc6397_pm3.png -a1 1 -a2 6 -d1 -20 -d2 -15

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_pm3.png')

# %% [markdown]
# ## 13.6. Further selection of stars by proper motion

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_13.py -i ngc6397_candidates.list -a1 1 -a2 6 -d1 -20 -d2 -15

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_14.py -i ngc6397_candidates.list -o ngc6397_pm4.png -a1 1 -a2 6 -d1 -20 -d2 -15 0.50 0.75 1.00 1.25 1.50

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_pm4.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_15.py -i ngc6397_candidates.list -o ngc6397_candidates2.list -a1 1 -a2 6 -d1 -20 -d2 -15 -r 1.00

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 ngc6397_candidates2.list | cut -b -80

# %%
# Run this cell to count the number of selected stars.

# !grep -v '#' ngc6397_candidates2.list | wc

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_16.py -i ngc6397_candidates2.list -o ngc6397_pm5.png

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_pm5.png')

# %% [markdown]
# ## 13.7. Constructing colour-magnitude diagram of NGC 6397

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_05_17.py -i ngc6397_candidates2.list -o ngc6397_hr.png -t "Globular Cluster NGC 6397"

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_hr.png')

# %% [markdown]
# ## 13.8. Superimposing synthetic main-sequence

# %%
# Run this cell to execute the script.

# !python3.14 appy_s11_06_02.py -i ngc6397_candidates2.list -m ms.data -o ngc6397_hr2.png -t "Globular Cluster NGC 6397"

# %%
# Run this cell to find newly created file.

# !ls -lF ngc6397*.png

# %%
# Run this cell to display image file.

# importing IPython module
import IPython.display

# displaying image file
IPython.display.Image ('ngc6397_hr2.png')

# %% [markdown]
# # End of this notebook
