# %% [markdown]
# # Doing Astrophysics using Python
#
# - "Doing Astrophysics using Python"
#   - Instructor: Kinoshita Daisuke
#   - Classroom: S4-202
#   - Time: from 13:00 to 15:50 on Wednesday
#   - Semester: 2nd semester of academic year 2025
#     - from February 2026 to June 2026
#   - Course web page: https://s3b.astro.ncu.edu.tw/appy_202602/
#   - GitHub repository: https://github.com/kinoshitadaisuke/ncu_doing_astrophysics_using_python_202602

# %% [markdown]
# # Session 02: "Importing and using Python modules"
#
# ## 04 March 2026
#
# ## Instructor: Kinoshita Daisuke

# %% [markdown]
# # 0. Installation of Python interpreter

# %%
# Run this cell to install Python 3.14

# !apt update
# !apt upgrade
# !apt install python3.14 python3.14-dev python3.14-full libpython3.14-dev
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.14 1
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.14 get-pip.py

# %%
# Run this cell to check the version of Python interpreter and pip command

# !python3.14 --version
# !pip --version

# %% [markdown]
# # 1. Downloading a set of sample Python scripts for this course

# %%
# Run this cell to download a set of sample Python scripts for this course.

# !git clone https://github.com/kinoshitadaisuke/ncu_doing_astrophysics_using_python_202602.git

# %%
# Run this cell to move to the directory for this session.

# %cd ncu_doing_astrophysics_using_python_202602/s02

# %%
# Run this cell to show a list of files for this session.

# !ls -lF

# %% [markdown]
# # 2. Using "os" module

# %% [markdown]
# ## 2.1 Currently working directory

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_00.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_01.py

# %% [markdown]
# ## 2.2 Getting a list of files and directories

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_02.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_03.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_04.py

# %% [markdown]
# ## 2.3 Getting file information

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_05.py

# %% [markdown]
# ## 2.4 Environmental variables

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_06.py

# %% [markdown]
# ## 2.5 Operating system information

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_07.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_07.py

# %% [markdown]
# ## 2.6 Creating a new directory

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_08.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_08.py

# %% [markdown]
# ## 2.7 Changing file mode

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_00_09.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_00_09.py

# %% [markdown]
# # 3. Using "sys" module

# %% [markdown]
# ## 3.1 Getting the version of Python interpreter

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_01_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_01_00.py

# %% [markdown]
# ## 3.2 Stopping Python interpreter

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_01_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_01_01.py

# %% [markdown]
# ## 3.3 Obtaining command-line arguments

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_01_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_01_02.py 1 2 3

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_01_02.py 1.23 4.56

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_01_02.py abc xyz

# %% [markdown]
# # 4. Using "argparse" module

# %% [markdown]
# ## 4.1 A simple example of using positional arguments

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_02_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_00.py 2 3

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_00.py 123 456

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_00.py 9876 5432

# %% [markdown]
# ## 4.2 A simple example of using optional arguments

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_02_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_01.py 30

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_01.py -f sin 30

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_01.py -f cos 90

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_01.py -f tan 45

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_01.py -f abc 60

# %% [markdown]
# ## 4.3 Making a calculator

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_02_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_02.py 3 + 4

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_02.py 5 - 6

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_02.py 7 x 8

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_02_02.py 9 / 2

# %% [markdown]
# # 5. Using "urllib" module

# %% [markdown]
# ## 5.1 Downloading a plain text file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_03_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_03_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF pi_1000.txt

# %%
# Run this cell to print the content of the file "pi_1000.txt".

# !cat pi_1000.txt

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_03_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_03_01.py

# %% [markdown]
# ## 5.2 Downloading a binary file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_03_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_03_02.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF ncu_map.png

# %%
# Run this cell to display an image file.

# importing IPython.display module
import IPython.display

# displaying an image file
IPython.display.Image ("ncu_map.png")

# %% [markdown]
# # 6. Using "pathlib" module

# %% [markdown]
# ## 6.1 Existence check of a file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_04_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_04_00.py

# %% [markdown]
# ## 6.2 Parent, name, suffix, and stem of a file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_04_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_04_01.py

# %% [markdown]
# ## 6.3 Finding directory contents

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_04_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_04_02.py

# %% [markdown]
# ## 6.4 File status information

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_04_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_04_03.py

# %% [markdown]
# ## 6.5 Opening and reading a file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_04_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_04_04.py

# %% [markdown]
# # 7. Using "shutil" module

# %% [markdown]
# ## 7.1 Copying a file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_05_00.py

# %%
# Run this cell to find files.

# !ls -lF *pi_1000*

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_05_00.py

# %%
# Run this cell to find files.

# !ls -lF *pi_1000*

# %% [markdown]
# ## 7.2 Finding location of an executable

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_05_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_05_01.py

# %% [markdown]
# # 8. Using "subprocess" module

# %% [markdown]
# ## 8.1 Executing a shell command

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_06_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_06_00.py

# %% [markdown]
# ## 8.2 Executing a command and capturing the output

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_06_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_06_01.py

# %% [markdown]
# # 9. Using "multiprocessing" module

# %% [markdown]
# ## 9.1 Finding prime numbers using one CPU core

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_07_00.py

# %%
# Run this cell to execute the script.

# !time python3.14 appy_s02_07_00.py

# %% [markdown]
# ## 9.2 Finding prime numbers using multiple CPU cores

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_07_01.py

# %%
# Run this cell to execute the script.

# !time python3.14 appy_s02_07_01.py

# %% [markdown]
# # 10. Using "datetime" module

# %% [markdown]
# ## 10.1 Knowing current local time

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_08_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_08_00.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_08_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_08_01.py

# %% [markdown]
# ## 10.2 Knowing current time in UTC

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_08_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_08_02.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_08_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_08_03.py

# %% [markdown]
# # 11. Using "csv" module

# %% [markdown]
# ## 11.1 Downloading a CSV file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_09_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_09_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.csv

# %%
# Run this cell to show the contents of the file "stars.csv".

# !cat stars.csv

# %% [markdown]
# ## 11.2 Reading a CSV file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_09_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_09_01.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_09_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_09_02.py

# %% [markdown]
# ## 11.3 Writing a CSV file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_09_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_09_03.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.data

# %%
# Run this cell to show the contents of the file "stars.csv".

# !cat planets_solsys.data

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_09_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_09_04.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_09_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_09_05.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.csv

# %%
# Run this cell to show the contents of the file "stars.csv".

# !cat planets_solsys.csv

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_09_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_09_06.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.csv

# %%
# Run this cell to show the contents of the file "stars.csv".

# !cat planets_solsys_2.csv

# %% [markdown]
# # 12. Using "json" module

# %% [markdown]
# ## 12.1 Downloading a JSON file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_10_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_10_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.json

# %%
# Run this cell to show the contents of the file "stars.csv".

# !cat stars.json

# %% [markdown]
# ## 12.2 Reading a JSON file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_10_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_10_01.py

# %% [markdown]
# ## 12.3 Writing a JSON file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_10_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_10_02.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.json

# %%
# Run this cell to show the contents of the file "stars.csv".

# !cat stars2.json

# %% [markdown]
# # 13. Using "gzip" module

# %% [markdown]
# ## 13.1 Decompressing a compressed file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_11_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_11_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.gz

# %%
# Run this cell to find newly downloaded file.

# !file numbers.data.gz

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_11_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_11_01.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_11_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_11_02.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.data

# %%
# Run this cell to find newly downloaded file.

# !cat numbers.data

# %% [markdown]
# ## 13.2 Compressing a file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_11_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_11_03.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF numbers*

# %%
# Run this cell to find newly downloaded file.

# !file numbers_2.data.gz

# %% [markdown]
# # 14. Using "tarfile" module

# %% [markdown]
# ## 14.1 Downloading a tar file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_12_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_12_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.tar

# %%
# Run this cell to find newly downloaded file.

# !file files.tar

# %% [markdown]
# ## 14.2 Finding files in a tar archive file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_12_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_12_01.py

# %% [markdown]
# ## 14.3 Extracting files in a tar archive file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_12_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_12_02.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF files

# %% [markdown]
# # 15. Using "zipfile" module

# %% [markdown]
# ## 15.1 Downloading a ZIP file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_13_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_13_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.zip

# %%
# Run this cell to find newly downloaded file.

# !file files2.zip

# %% [markdown]
# ## 15.2 Finding files in a ZIP file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_13_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_13_01.py

# %% [markdown]
# ## 15.3 Extracting files in a ZIP file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_13_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_13_02.py

# %%
# Run this cell to find extracted files.

# !ls -lF files2

# %% [markdown]
# # 16. Using "re" module

# %% [markdown]
# ## 16.1 Downloading Bright Star Catalogue

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_14_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_14_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF catalog.gz

# %% [markdown]
# ## 16.2 Existence check of downloaded file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_14_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_14_01.py

# %% [markdown]
# ## 16.3 Reading a compressed file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_14_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_14_02.py

# %%
# Run this cell to find de-compressed file.

# !ls -lF catalog.gz bsc.data

# %% [markdown]
# ## 16.4 Pattern matching using regular expression

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_14_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_14_03.py

# %% [markdown]
# ## 16.5 Finding O-type main-sequence stars

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_14_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_14_04.py

# %% [markdown]
# ## 16.6 Finding M-type supergiants

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_14_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_14_05.py

# %% [markdown]
# ## 16.7 Finding very bright main-sequence stars

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_14_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_14_06.py

# %% [markdown]
# # 17. Using "math" module

# %% [markdown]
# ## 17.1 Constants

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_00.py

# %% [markdown]
# ## 17.2 Useful functions

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_01.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_02.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_03.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_04.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_05.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_06.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_07.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_07.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_08.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_08.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_09.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_09.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_10.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_10.py

# %% [markdown]
# ## 17.3 Mathematical functions

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_11.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_11.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_12.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_12.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_13.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_13.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_14.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_14.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_15.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_15.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_16.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_16.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_15_17.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_15_17.py

# %% [markdown]
# # 18. Using "random" module

# %% [markdown]
# ## 18.1 Random numbers of uniform distribution between 0 and 1

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_16_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_16_00.py

# %% [markdown]
# ## 18.2 Random numbers of uniform distribution between 100 and 200

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_16_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_16_01.py

# %% [markdown]
# ## 18.3 Random numbers of Gaussian distribution

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_16_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_16_02.py

# %% [markdown]
# # 19. Using "statistics" module

# %% [markdown]
# ## 19.1 Calculations of statistical values

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_17_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_17_00.py

# %% [markdown]
# ## 19.2 Generating random numbers and calculating statistical values

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_17_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_17_01.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_17_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_17_02.py

# %% [markdown]
# # 20. Using "decimal" module

# %% [markdown]
# ## 20.1 Arithmetic calculations

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_18_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_18_00.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_18_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_18_01.py

# %% [markdown]
# ## 20.2 Square-root and logarithmic calculation

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_18_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_18_02.py

# %% [markdown]
# ## 20.3 Value of pi

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_18_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_18_03.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_18_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_18_04.py

# %% [markdown]
# # 21. Using "uncertainties" package

# %% [markdown]
# ## 21.1 Installation of "uncertainties" package

# %%
# Run this cell to install "uncertainties" module.

# !pip install uncertainties

# %% [markdown]
# ## 21.2 Using "uncertainties" package

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_19_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_19_00.py

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_19_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_19_01.py

# %% [markdown]
# # 22. Using "pint" package

# %% [markdown]
# ## 22.1 Installation of "pint" package

# %%
# Run this cell to install "pint" module.

# !pip install pint

# %% [markdown]
# ## 22.2 Angles

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_20_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_20_00.py

# %% [markdown]
# ## 22.3 Distance

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_20_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_20_01.py

# %% [markdown]
# ## 22.4 Velocity

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_20_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_20_02.py

# %% [markdown]
# # 23. Using "mpmath" package

# %% [markdown]
# ## 23.1 Installation of "mpmath" package

# %%
# Run this cell to install "mpmath" package.

# !pip install mpmath

# %% [markdown]
# ## 23.2 Calculation of approximate value of pi

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_21_00.py

# %%
# Run this cell to execute the script.

#
# It takes about 30 min to execute this cell.
#

# !python3.14 appy_s02_21_00.py

# %% [markdown]
# # 24. Using "sympy" package

# %% [markdown]
# ## 24.1 Installation of "sympy" package

# %%
# Run this cell to install "sympy" package.

# !pip install sympy

# %% [markdown]
# ## 24.2 Calculation of (x+1)**2

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_00.py

# %% [markdown]
# ## 24.3 Factorisation of x**2 + x - 2

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_01.py

# %% [markdown]
# ## 24.4 lim (1+1/x)**x

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_02.py

# %% [markdown]
# ## 24.5 Solving a*x**2 + b*x + c = 0

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_03.py

# %% [markdown]
# ## 24.6 Differentiation

# %% [markdown]
# ## d/dx (1/x)

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_04.py

# %% [markdown]
# ## d/dx [sin(x)]

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_05.py

# %% [markdown]
# ## d/dx [log(x)]

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_06.py

# %% [markdown]
# ## 24.7 Integration

# %% [markdown]
# ## Integration of x**2

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_07.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_07.py

# %% [markdown]
# ## Integration of sin(x)

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_08.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_08.py

# %% [markdown]
# ## Integration of 1/x

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_09.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_09.py

# %% [markdown]
# ## 24.8 Solving a differential equation

# %% [markdown]
# ## Solving dy/dx = -ky

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_10.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_10.py

# %% [markdown]
# ## Solving Lane-Emden equation of n=0

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_11.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_11.py

# %% [markdown]
# ## 24.9 definite integral

# %% [markdown]
# ## definite integral 1

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_12.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_12.py

# %% [markdown]
# ## definite integral 2

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_13.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_13.py

# %% [markdown]
# ## definite integral 3

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_14.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_14.py

# %% [markdown]
# ## definite integral 4

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_15.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_15.py

# %% [markdown]
# ## defenite integral 5

# %%
# Run this cell to show the source code of the script.

# !cat appy_s02_22_16.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s02_22_16.py

# %% [markdown]
# # End of this notebook
