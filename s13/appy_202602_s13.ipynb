# %% [markdown]
# # Doing Astrophysics using Python
#
# - "Doing Astrophysics using Python"
#   - Instructor: Kinoshita Daisuke
#   - Classroom: S4-202
#   - Time: from 13:00 to 15:50 on Wednesday
#   - Semester: 2nd semester of academic year 2025
#     - from February 2026 to June 2026
#   - Course web page: https://s3b.astro.ncu.edu.tw/appy_202602/
#   - GitHub repository: https://github.com/kinoshitadaisuke/ncu_doing_astrophysics_using_python_202602

# %% [markdown]
# # Session 13: "Source extraction and image alignment of astronomical images"
#
# ## 20 May 2026
#
# ## Instructor: Kinoshita Daisuke

# %% [markdown]
# # 0. Installation of Python interpreter

# %%
# Run this cell to install Python 3.14

# !apt update
# !apt upgrade
# !apt install python3.14 python3.14-dev python3.14-full libpython3.14-dev
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.14 1
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.14 get-pip.py

# %%
# Run this cell to check the version of Python interpreter and pip command

# !python3.14 --version
# !pip --version

# %%
# Run this cell to install external Python packages.

# !pip install matplotlib matplotlib-inline numpy scipy astropy astroquery importlib_metadata photutils astroalign scikit-image

# %% [markdown]
# # 1. Downloading a set of sample Python scripts for this course

# %%
# Run this cell to download a set of sample Python scripts for this course.

# !git clone https://github.com/kinoshitadaisuke/ncu_doing_astrophysics_using_python_202602.git

# %%
# Run this cell to move to the directory for this session.

# %cd ncu_doing_astrophysics_using_python_202602/s13

# %%
# Run this cell to show a list of files for this session.

# !ls -lF

# %% [markdown]
# # 2. Making a synthetic image

# %% [markdown]
# ## 2.1 Installation of "photutils" package
#
# Visit following web page and learn about "photutils".
#
# https://photutils.readthedocs.io/

# %% [markdown]
# ## 2.2 Making a sky background image

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_00_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_00.py -b 3000 -s 50 -x 1024 -y 1024 -o synthetic_skybg.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.fits

# %% [markdown]
# ## 2.3 Printing the header part of a FITS file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_00_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_01.py synthetic_skybg.fits

# %% [markdown]
# ## 2.4 Examining pixel values of a FITS file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_00_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_02.py synthetic_skybg.fits

# %% [markdown]
# ## 2.5 Visualising a FITS file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_00_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -i synthetic_skybg.fits -o synthetic_skybg.png -c hot -t "synthetic sky background image"

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_skybg.png')

# %% [markdown]
# ## 2.6 Making a synthetic image with artificial stars

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_00_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_04.py -b 3000 -s 50 -n 300 -f 50000 -p 4 -x 1024 -y 1024 -o synthetic_star.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -i synthetic_star.fits -o synthetic_star.png -c bone -t "synthetic image with stars"

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_star.png')

# %% [markdown]
# ## 2.7 Making a synthetic image with artificial stars and galaxies

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_00_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_05.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_05.py -s 3000 -e 50 -n 200 -g 30 -l synthetic_star_gal.log -o synthetic_star_gal.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -i synthetic_star_gal.fits -o synthetic_star_gal.png -c viridis -t "synthetic image with stars and galaxies"

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_star_gal.png')

# %% [markdown]
# # 3. Estimating sky background level

# %% [markdown]
# ## 3.1 Estimating 1-D sky background value

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_01_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_01_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_01_00.py -i synthetic_star_gal.fits -o synthetic_star_gal_masked.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_01.py synthetic_star_gal_masked.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -i synthetic_star_gal_masked.fits -o synthetic_star_gal_masked.png -t 'masking stars and galaxies'

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_star_gal_masked.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_01_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_01_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_01_01.py -i synthetic_star_gal.fits

# %% [markdown]
# ## 3.2 Making 2-D sky background map

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_01_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_01_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_01_02.py -i synthetic_star_gal.fits -o synthetic_star_gal_skybg.fits -b 100

# %%
# Run this cell to find newly created file.

# !ls -lF *.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -i synthetic_star_gal_skybg.fits -o synthetic_star_gal_skybg.png

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_star_gal_skybg.png')

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_01_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_01_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_01_03.py -i synthetic_star_gal.fits -o synthetic_star_gal_skysub.fits -b 100

# %%
# Run this cell to find newly created file.

# !ls -lF *.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_01.py synthetic_star_gal_skysub.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -i synthetic_star_gal_skysub.fits -o synthetic_star_gal_skysub.png

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_star_gal_skysub.png')

# %% [markdown]
# # 4. Source extraction

# %% [markdown]
# ## 4.1 Detecting sources using image segmentation

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_02_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_00.py -i synthetic_star_gal.fits -o synthetic_star_gal_segm.png

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_star_gal_segm.png')

# %% [markdown]
# ## 4.2 De-blending

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_02_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_01.py -i synthetic_star_gal.fits -o synthetic_star_gal_deblend.png

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_star_gal_deblend.png')

# %% [markdown]
# ## 4.3 Making a source catalogue

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_02_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_02.py -i synthetic_star_gal.fits -o synthetic_star_gal.cat

# %%
# Run this cell to find newly created file.

# !ls -lF *.cat

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 synthetic_star_gal.cat

# %% [markdown]
# ## 4.4 Reading a source catalogue file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_02_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_03.py -i synthetic_star_gal.cat

# %% [markdown]
# ## 4.5 Finding locations of detected sources

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_02_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_04.py -i synthetic_star_gal.fits -c synthetic_star_gal.cat -o synthetic_star_gal_sources.png -r 30

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('synthetic_star_gal_sources.png')

# %% [markdown]
# # 5. Source extraction for real data

# %% [markdown]
# ## 5.1 Downloading SDSS image of PG1047+003 field

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_03_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_03_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_03_00.py -s SDSSi -t PG1047+003 -f 2048 -o pg1047_sdss_i.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -i pg1047_sdss_i.fits -o pg1047_sdss_i.png -t "PG1047+003 (SDSS i)"

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('pg1047_sdss_i.png')

# %% [markdown]
# ## 5.2 Source extraction for SDSS image of PG1047+003 field

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_02.py -i pg1047_sdss_i.fits -o pg1047_sdss_i.cat

# %%
# Run this cell to find newly created file.

# !ls -lF *.cat

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 pg1047_sdss_i.cat

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_04.py -i pg1047_sdss_i.fits -c pg1047_sdss_i.cat -o pg1047_sdss_i_sources.png -r 30

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('pg1047_sdss_i_sources.png')

# %% [markdown]
# ## 5.3 Downloading SDSS image of PG1528+062 field

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_03_00.py -s SDSSi -t PG1528+062 -f 2048 -o pg1528_sdss_i.fits

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_03.py -i pg1528_sdss_i.fits -o pg1528_sdss_i.png -t "PG1528+062 (SDSS i)"

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('pg1528_sdss_i.png')

# %% [markdown]
# ## 5.4 Source extraction for SDSS image of PG1528+062 field

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_02.py -i pg1528_sdss_i.fits -o pg1528_sdss_i.cat

# %%
# Run this cell to find newly created file.

# !ls -lF *.cat

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 pg1528_sdss_i.cat

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_04.py -i pg1528_sdss_i.fits -c pg1528_sdss_i.cat -o pg1528_sdss_i_sources.png -r 30

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('pg1528_sdss_i_sources.png')

# %% [markdown]
# # 6. Generating a set of synthetic images for image alignment

# %% [markdown]
# ## 6.1 Generating (x, y) positions of artificial stars

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_04_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_00.py -n 50 -x 2048 -y 2048 -o stars_0.list

# %%
# Run this cell to find newly created file.

# !ls -lF *.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 stars_0.list

# %% [markdown]
# ## 6.2 Rotation and translation of locations of articial stars

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_04_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_01.py -i stars_0.list -o stars_1.list -c 800 -d 1200 -r 20 -s 100 -t 200

# %%
# Run this cell to find newly created file.

# !ls -lF *.list

# %%
# Run this cell to show first 20 lines of newly created file.

# !head -20 stars_1.list

# %% [markdown]
# ## 6.3 Making synthetic images

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_04_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_02.py -i stars_0.list -o stars_0.fits -f 3.5 -s 4000 -e 70
# !python3.14 appy_s13_04_02.py -i stars_1.list -o stars_1.fits -f 4.5 -s 3000 -e 60

# %%
# Run this cell to find newly created file.

# !ls -lF *.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_01.py stars_0.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_01.py stars_1.fits

# %% [markdown]
# ## 6.4 Visualising two FITS files

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_04_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_03.py -t "First image" -u "Second image" -o stars_0_1.png stars_0.fits stars_1.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('stars_0_1.png')

# %% [markdown]
# # 7. Alignment of two astronomical images

# %% [markdown]
# ## 7.1 Source extraction

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_02.py -i stars_0.fits -o stars_0.cat
# !python3.14 appy_s13_02_02.py -i stars_1.fits -o stars_1.cat

# %%
# Run this cell to find newly created file.

# !ls -lF *.cat

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_04.py -i stars_0.fits -c stars_0.cat -o stars_0_sources.png -r 30
# !python3.14 appy_s13_02_04.py -i stars_1.fits -c stars_1.cat -o stars_1_sources.png -r 30

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('stars_0_sources.png')

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('stars_1_sources.png')

# %% [markdown]
# ## 7.2 Finding star-to-star correspondence

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_04_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_04.py stars_0.cat stars_1.cat

# %% [markdown]
# ## 7.3 Checking results of star-to-star correspondence

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_04_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_05.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_05.py -o stars_0_1_match.png stars_0.cat stars_1.cat stars_0.fits stars_1.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('stars_0_1_match.png')

# %% [markdown]
# ## 7.4 Aligning images

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_04_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_06.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_06.py -o stars_0_1_align.png stars_0.cat stars_1.cat stars_0.fits stars_1.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('stars_0_1_align.png')

# %% [markdown]
# ## 7.5 Aligning images and creating a new FITS file

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_04_07.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_07.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_07.py -o stars_1_aligned.fits stars_0.cat stars_1.cat stars_0.fits stars_1.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_00_01.py stars_1_aligned.fits

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_03.py -t "First image" -u "Aligned second image" -c viridis -o stars_0_1_align2.png stars_0.fits stars_1_aligned.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('stars_0_1_align2.png')

# %% [markdown]
# # 8. Image alignment of real astronomical images

# %% [markdown]
# ## 8.1 Downloading SDSS g'-band image

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_05_00.py -s SDSSg -t PG0231+051 -f 2048 -o pg0231_sdss_g.fits

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.fits

# %% [markdown]
# ## 8.2 Downloading SDSS i'-band image

# %%
# Run this cell to show the source code of the script.

# !cat appy_s13_05_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_05_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_05_01.py -s SDSSi -t PG0231+051 -f 2048 -o pg0231_sdss_i.fits -x 2 -y -5

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.fits

# %% [markdown]
# ## 8.3 Visualising two SDSS images

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_04_03.py -t "SDSS g" -u "SDSS i" -c bone -o pg0231_sdss_g_i.png pg0231_sdss_g.fits pg0231_sdss_i.fits

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('pg0231_sdss_g_i.png')

# %% [markdown]
# ## 8.4 Source extraction

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_02.py -i pg0231_sdss_g.fits -o pg0231_sdss_g.cat -t 3
# !python3.14 appy_s13_02_02.py -i pg0231_sdss_i.fits -o pg0231_sdss_i.cat -t 3

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_04.py -i pg0231_sdss_g.fits -c pg0231_sdss_g.cat -o pg0231_sdss_g_sources.png -r 30
# !python3.14 appy_s13_02_04.py -i pg0231_sdss_i.fits -c pg0231_sdss_i.cat -o pg0231_sdss_i_sources.png -r 30

# %%
# Run this cell to find newly created file.

# !ls -lF *.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('pg0231_sdss_g_sources.png')

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('pg0231_sdss_i_sources.png')

# %% [markdown]
# ## 8.5 Finding star-to-star correspondence

# %%
# Run this cell to execute the script.

# !cat appy_s13_05_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_05_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_05_02.py -n 300 pg0231_sdss_g.cat pg0231_sdss_i.cat

# %% [markdown]
# ## 8.6 Checking results of star-to-star correspondence

# %%
# Run this cell to execute the script.

# !cat appy_s13_05_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_05_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_05_03.py -n 300 -o pg0231_sdss_g_i_match.png pg0231_sdss_g.cat pg0231_sdss_i.cat pg0231_sdss_g.fits pg0231_sdss_i.fits

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('pg0231_sdss_g_i_match.png')

# %% [markdown]
# # 9. HST and JWST images

# %% [markdown]
# ## 9.1 Finding coordinates using name resolver

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_00.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_00.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_00.py -t "SMACS 0723"

# %% [markdown]
# ## 9.2 Downloading HST image of SMACS 0723

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_01.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_01.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_01.py -t "SMACS 0723" -s 0.1

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_02.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_02.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_02.py -t "SMACS 0723" -s 0.1

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_03.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_03.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_03.py -t "SMACS 0723" -s 0.1

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_04.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_04.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_04.py -t "SMACS 0723" -s 0.1 -i 25856819

# %%
# Run this cell to find newly downloaded files.

# !ls -lF mastDownload

# %%
# Run this cell to find newly downloaded files.

# !ls -lF mastDownload/HST

# %%
# Run this cell to find newly downloaded files.

# !ls -lF mastDownload/HST/hst_14096_z4_wfc3_ir_total_iczgz4

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_05.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_05.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_05.py -i mastDownload/HST/hst_14096_z4_wfc3_ir_total_iczgz4/hst_14096_z4_wfc3_ir_total_iczgz4_drz.fits -o smacs0723_hst.png

# %%
# Run this cell to find newly created file.

# !ls -lF smacs0723*.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('smacs0723_hst.png')

# %% [markdown]
# ## 9.3 Downloading JWST image

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_06.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_06.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_06.py -t "SMACS 0723" -s 0.1

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_07.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_07.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_07.py -t "SMACS 0723" -s 0.1

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_08.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_08.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_08.py -t "SMACS 0723" -s 0.1 -i 87602570

# %%
# Run this cell to find newly downloaded files.

# !ls -lF mastDownload

# %%
# Run this cell to find newly downloaded files.

# !ls -lF mastDownload/JWST

# %%
# Run this cell to find newly downloaded files.

# !ls -lF mastDownload/JWST/jw02736001001_02103_00006_nrcb2

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_05.py -i mastDownload/JWST/jw02736001001_02103_00006_nrcb2/jw02736001001_02103_00006_nrcb2_i2d.fits -o smacs0723_jwst.png

# %%
# Run this cell to find newly created file.

# !ls -lF smacs0723*.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('smacs0723_jwst.png')

# %% [markdown]
# ## 9.4 Source extraction

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_02.py -i mastDownload/HST/hst_14096_z4_wfc3_ir_total_iczgz4/hst_14096_z4_wfc3_ir_total_iczgz4_drz.fits -o smacs0723_hst.cat -t 5

# %%
# Run this cell to find newly created file.

# !ls -lF smacs0723*.cat

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_04.py -i mastDownload/HST/hst_14096_z4_wfc3_ir_total_iczgz4/hst_14096_z4_wfc3_ir_total_iczgz4_drz.fits -c smacs0723_hst.cat -o smacs0723_hst_sources.png -r 30

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('smacs0723_hst_source.png')

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_02_02.py -i mastDownload/JWST/jw02736001001_02103_00006_nrcb2/jw02736001001_02103_00006_nrcb2_i2d.fits -o smacs0723_jwst.cat -t 5

# %%
# Run this cell to find newly created file.

# !ls -lF smacs0723*.cat

# %%
# Run this cell to execute the script.

# !python3.14 ppy_s13_02_04.py -i mastDownload/JWST/jw02736001001_02103_00006_nrcb2/jw02736001001_02103_00006_nrcb2_i2d.fits -c smacs0723_jwst.cat -o smacs0723_jwst_sources.png -r 30

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('smacs0723_jwst_source.png')

# %% [markdown]
# ## 9.5 Star-to-star matching

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_09.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_09.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_09.py -n 500 smacs0723_hst.cat smacs0723_jwst.cat

# %%
# Run this cell to execute the script.

# !cat appy_s13_06_10.py

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_10.py -h

# %%
# Run this cell to execute the script.

# !python3.14 appy_s13_06_10.py -n 500 -o smacs0723_hst_jwst.png smacs0723_hst.cat smacs0723_jwst.cat mastDownload/HST/hst_14096_z4_wfc3_ir_total_iczgz4/hst_14096_z4_wfc3_ir_total_iczgz4_drz.fits mastDownload/JWST/jw02736001001_02103_00006_nrcb2/jw02736001001_02103_00006_nrcb2_i2d.fits

# %%
# Run this cell to find newly created file.

# !ls -lF smacs0723*.png

# %%
# Run this cell to display PNG file.

# importing IPython module
import IPython.display

# displaying PNG file
IPython.display.Image ('smacs0723_hst_jwst.png')

# %% [markdown]
# # End of this notebook
